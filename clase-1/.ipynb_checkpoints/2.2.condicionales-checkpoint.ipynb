# %% [markdown]
# ## Condicionales

# %%
# Introducción
name = input('Digite su nombre')
n = int(input('Digite la cantidad de veces que quiere ver su nombre: '))
for i in range(n):
    print(f'Hola {name}!')
# Out:
# Digite su nombre Josué
# Digite la cantidad de veces que quiere ver su nombre:  3
# Hola Josué!
# Hola Josué!
# Hola Josué!
