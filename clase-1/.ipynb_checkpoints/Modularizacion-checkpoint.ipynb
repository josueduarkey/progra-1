# %%
carnet = input('Digite su carnet: ')
name = input('Digite su nombre: ')

print(f'Estudiante 1: KEY_{carnet} - {name}')
rand
# Out:
# Digite su carnet:  00207
# Digite su nombre:  Josué
# Hola Josué, Su carnet es: KEY_00207
