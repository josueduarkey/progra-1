# %% [markdown]
# ### 1.5.1 Tipos de datos en python

# %%
# datos enteros
a = 10
b = -1
c = 1000

# %%
# datos float
d = 1.34
PI = 3.1416

# %%
# cadenas de texto - String
texto = 'fundamentos de programación'

# %%
# Datos booleanos
is_number = True
is_animal = False

# %%
# Colecciones: Listas
lista = ['josué', 'claros', 'kevin', 'roberto', 'jeremy']
lista2 = [1, True, 'texto', 3.14]
print(lista)

# %% [markdown]
# ### 1.5.2 Entrada desde el teclado

# %%
name = input('Ingrese su nombre:') # Todo lo convierte a texto
age = input('Ingrese su edad')
# Out:
# Ingrese su nombre: Kevin
# Ingrese su edad 19

# %%
print(f'Bienvenido {name} a Key Institute tu edad en 2027 será {int(age) + 1}')
# Out:
# Bienvenido Kevin a Key Institute tu edad en 2027 será 20
