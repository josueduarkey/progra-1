# %%
print('testing jupyter lab')
# Out:
# testing jupyter lab

# %%
a = 10
b = 30

# %%
print(f'La suma de {a} + {b} es: {a + b}')
# Out:
# La suma de [1 2 3 4] + 30 es: [31 32 33 34]

# %%
import numpy as np
a = np.array([1, 2, 3, 4])

# Element-wise operations
print(a * 2)  

# Multi-dimensional array
res = np.array([[1, 2], [3, 4]])
print(res * 2)
# Out:
# [2 4 6 8]
# [[2 4]
#  [6 8]]
