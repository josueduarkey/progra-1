# %%
from random import randint

def new_student(id) :
    carnet = input('Digite su carnet: ')
    name = input('Digite su nombre: ')
    print(f'Estudiante {id}: KEY_{carnet} - {name}')

new_student(1)
new_student(2)
new_student(3)
# Out:
# Digite su carnet:  002
# Digite su nombre:  Josué
# Estudiante 810: KEY_002 - Josué
# Digite su carnet:  003
# Digite su nombre:  Kevin
# Estudiante 843: KEY_003 - Kevin
# Digite su carnet:  003
# Digite su nombre:  Andrés
# Estudiante 93: KEY_003 - Andrés
