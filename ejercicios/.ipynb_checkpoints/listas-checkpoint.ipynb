# %% [markdown]
# # Listas

# %% [raw]
# Accediendo a valores en una lista

# %%
aulas = ['R101', 'CLIC', 'KITE', 'SPARK', 'ACTION', 'NOSE']

# %%
for i in aulas:
    print(i)
# Out:
# R101
# CLIC
# KITE
# SPARK
# ACTION
